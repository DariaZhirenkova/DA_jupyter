# %%
import pandas as pd

# %%
booking = pd.read_csv('C:/bookings.csv',sep = ';')

# %%
booking
# Out:
#                Hotel  Is Canceled  Lead Time arrival full date  \
# 0       Resort Hotel            0        342        2015-07-01
# 1       Resort Hotel            0        737        2015-07-01
# 2       Resort Hotel            0          7        2015-07-01
# 3       Resort Hotel            0         13        2015-07-01
# 4       Resort Hotel            0         14        2015-07-01
# ...              ...          ...        ...               ...
# 119385    City Hotel            0         23        2017-08-30
# 119386    City Hotel            0        102        2017-08-31
# 119387    City Hotel            0         34        2017-08-31
# 119388    City Hotel            0        109        2017-08-31
# 119389    City Hotel            0        205        2017-08-29
#
#         Arrival Date Year Arrival Date Month  Arrival Date Week Number  \
# 0                    2015               July                        27
# ...

# %%
booking.shape
# Out:
# (119390, 21)

# %%
booking.dtypes.value_counts()
# Out:
# object     10
# int64      10
# float64     1
# Name: count, dtype: int64

# %%
booking[:7]
# Out:
#           Hotel  Is Canceled  Lead Time arrival full date  Arrival Date Year  \
# 0  Resort Hotel            0        342        2015-07-01               2015
# 1  Resort Hotel            0        737        2015-07-01               2015
# 2  Resort Hotel            0          7        2015-07-01               2015
# 3  Resort Hotel            0         13        2015-07-01               2015
# 4  Resort Hotel            0         14        2015-07-01               2015
# 5  Resort Hotel            0         14        2015-07-01               2015
# 6  Resort Hotel            0          0        2015-07-01               2015
#
#   Arrival Date Month  Arrival Date Week Number  Arrival Date Day of Month  \
# 0               July                        27                          1
# 1               July                        27                          1
# 2               July                        27                          1
# ...

# %%
booking.head(7)
# Out:
#           Hotel  Is Canceled  Lead Time arrival full date  Arrival Date Year  \
# 0  Resort Hotel            0        342        2015-07-01               2015
# 1  Resort Hotel            0        737        2015-07-01               2015
# 2  Resort Hotel            0          7        2015-07-01               2015
# 3  Resort Hotel            0         13        2015-07-01               2015
# 4  Resort Hotel            0         14        2015-07-01               2015
# 5  Resort Hotel            0         14        2015-07-01               2015
# 6  Resort Hotel            0          0        2015-07-01               2015
#
#   Arrival Date Month  Arrival Date Week Number  Arrival Date Day of Month  \
# 0               July                        27                          1
# 1               July                        27                          1
# 2               July                        27                          1
# ...

# %%
def rename_columns(col):
    return col.lower().replace(" ", "_")

# %%
rename_columns('Aee rr tt Y')
# Out:
# 'aee_rr_tt_y'

# %%
booking = booking.rename(columns = rename_columns)

# %%
booking
# Out:
#                hotel  is_canceled  lead_time arrival_full_date  \
# 0       Resort Hotel            0        342        2015-07-01
# 1       Resort Hotel            0        737        2015-07-01
# 2       Resort Hotel            0          7        2015-07-01
# 3       Resort Hotel            0         13        2015-07-01
# 4       Resort Hotel            0         14        2015-07-01
# ...              ...          ...        ...               ...
# 119385    City Hotel            0         23        2017-08-30
# 119386    City Hotel            0        102        2017-08-31
# 119387    City Hotel            0         34        2017-08-31
# 119388    City Hotel            0        109        2017-08-31
# 119389    City Hotel            0        205        2017-08-29
#
#         arrival_date_year arrival_date_month  arrival_date_week_number  \
# 0                    2015               July                        27
# ...

# %%
booking.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_full_date',
#        'arrival_date_year', 'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'stays_total_nights', 'adults', 'children',
#        'babies', 'meal', 'country', 'reserved_room_type', 'assigned_room_type',
#        'customer_type', 'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
booking\
.query('is_canceled == 0')\
.groupby('country',as_index = False)\
.agg({'is_canceled':'count'})[:5]
# Out:
#   country  is_canceled
# 0     ABW            2
# 1     AGO          157
# 2     AIA            1
# 3     ALB           10
# 4     AND            2

# %%
booking\
.query('is_canceled == 0')\
.country\
.value_counts()[:5]
# Out:
# country
# PRT    21071
# GBR     9676
# FRA     8481
# ESP     6391
# DEU     6069
# Name: count, dtype: int64

# %%
booking.groupby('hotel').agg({'stays_total_nights':'mean'}).round(2)
# Out:
#               stays_total_nights
# hotel
# City Hotel                  2.98
# Resort Hotel                4.32

# %%
booking.query('assigned_room_type != reserved_room_type').shape[0]
# Out:
# 14917

# %%
booking.query('arrival_date_year == 2016 & is_canceled == 0').groupby('arrival_date_month').agg({"is_canceled":"count"}).sort_values('is_canceled',ascending = False)[:1]
# Out:
#                     is_canceled
# arrival_date_month
# October                    3689

# %%
booking.query('arrival_date_year == 2017 & is_canceled == 0').groupby('arrival_date_month').agg({"is_canceled":"count"}).sort_values('is_canceled',ascending = False)[:1]
# Out:
#                     is_canceled
# arrival_date_month
# May                        3551

# %%
booking.query('arrival_date_year == 2017 & is_canceled == 0').arrival_date_month.value_counts()[:1]
# Out:
# arrival_date_month
# May    3551
# Name: count, dtype: int64

# %%
booking.query('is_canceled == 1 & hotel == "City Hotel"').groupby(['arrival_date_year','arrival_date_month']).agg({"is_canceled":"count"}).sort_values(['arrival_date_year','arrival_date_month'],ascending =False)
# Out:
#                                       is_canceled
# arrival_date_year arrival_date_month
# 2017              May                        2217
#                   March                      1278
#                   June                       1808
#                   July                       1324
#                   January                    1044
#                   February                    971
#                   August                     1123
#                   April                      1926
# 2016              September                  1567
#                   October                    1947
#                   November                   1360
#                   May                        1436
#                   March                      1108
#                   June                       1720
#                   July                       1043
#                   January                     438
#                   February                    930
# ...

# %%
booking.query('is_canceled == 1 & hotel == "City Hotel"').groupby('arrival_date_year').arrival_date_month.value_counts()
# Out:
# arrival_date_year  arrival_date_month
# 2015               September             1543
#                    October               1321
#                    August                1232
#                    July                   939
#                    December               668
#                    November               301
# 2016               October               1947
#                    June                  1720
#                    September             1567
#                    April                 1539
#                    May                   1436
#                    November              1360
#                    August                1247
#                    March                 1108
#                    December              1072
#                    July                  1043
#                    February               930
#                    January                438
# 2017               May                   2217
#                    April                 1926
# ...

# %%
booking[:3]
# Out:
#           hotel  is_canceled  lead_time arrival_full_date  arrival_date_year  \
# 0  Resort Hotel            0        342        2015-07-01               2015
# 1  Resort Hotel            0        737        2015-07-01               2015
# 2  Resort Hotel            0          7        2015-07-01               2015
#
#   arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0               July                        27                          1
# 1               July                        27                          1
# 2               July                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  ...  adults  children  \
# 0                        0                     0  ...       2       0.0
# 1                        0                     0  ...       2       0.0
# 2                        0                     1  ...       1       0.0
#
# ...

# %%
booking.adults.mean()
# Out:
# 1.8564033838679956

# %%
booking.children.mean()
# Out:
# 0.10388990333874994

# %%
booking.babies.mean()
# Out:
# 0.007948739425412514

# %%
booking[['adults','children','babies']].mean()
# Out:
# adults      1.856403
# children    0.103890
# babies      0.007949
# dtype: float64

# %%
booking[['adults','children','babies']].describe()
# Out:
#               adults       children         babies
# count  119390.000000  119386.000000  119390.000000
# mean        1.856403       0.103890       0.007949
# std         0.579261       0.398561       0.097436
# min         0.000000       0.000000       0.000000
# 25%         2.000000       0.000000       0.000000
# 50%         2.000000       0.000000       0.000000
# 75%         2.000000       0.000000       0.000000
# max        55.000000      10.000000      10.000000

# %%
booking['total_kids'] = booking['children']+booking['babies']

# %%
booking
# Out:
#                hotel  is_canceled  lead_time arrival_full_date  \
# 0       Resort Hotel            0        342        2015-07-01
# 1       Resort Hotel            0        737        2015-07-01
# 2       Resort Hotel            0          7        2015-07-01
# 3       Resort Hotel            0         13        2015-07-01
# 4       Resort Hotel            0         14        2015-07-01
# ...              ...          ...        ...               ...
# 119385    City Hotel            0         23        2017-08-30
# 119386    City Hotel            0        102        2017-08-31
# 119387    City Hotel            0         34        2017-08-31
# 119388    City Hotel            0        109        2017-08-31
# 119389    City Hotel            0        205        2017-08-29
#
#         arrival_date_year arrival_date_month  arrival_date_week_number  \
# 0                    2015               July                        27
# ...

# %%
booking.groupby('hotel').total_kids.mean().round(2)
# Out:
# hotel
# City Hotel      0.10
# Resort Hotel    0.14
# Name: total_kids, dtype: float64

# %%
for i in booking.total_kids:
    if i >= 1:
        has_kids=True
    else:
        has_kids = False

# %%
has_kids
# Out:
# False

# %%
booking['has_kids'] = has_kids

# %%
booking
# Out:
#                hotel  is_canceled  lead_time arrival_full_date  \
# 0       Resort Hotel            0        342        2015-07-01
# 1       Resort Hotel            0        737        2015-07-01
# 2       Resort Hotel            0          7        2015-07-01
# 3       Resort Hotel            0         13        2015-07-01
# 4       Resort Hotel            0         14        2015-07-01
# ...              ...          ...        ...               ...
# 119385    City Hotel            0         23        2017-08-30
# 119386    City Hotel            0        102        2017-08-31
# 119387    City Hotel            0         34        2017-08-31
# 119388    City Hotel            0        109        2017-08-31
# 119389    City Hotel            0        205        2017-08-29
#
#         arrival_date_year arrival_date_month  arrival_date_week_number  \
# 0                    2015               July                        27
# ...

# %%
booking['has_kids'] = booking.total_kids>0

# %%
proc = (booking.query('is_canceled == 1').shape[0]/booking.shape[0]*100)

# %%
proc1 = round(proc,2)

# %%
proc1
# Out:
# 37.04

# %%
booking.query('is_canceled == 0').count()
# Out:
# hotel                        75166
# is_canceled                  75166
# lead_time                    75166
# arrival_full_date            75166
# arrival_date_year            75166
# arrival_date_month           75166
# arrival_date_week_number     75166
# arrival_date_day_of_month    75166
# stays_in_weekend_nights      75166
# stays_in_week_nights         75166
# stays_total_nights           75166
# adults                       75166
# children                     75166
# babies                       75166
# meal                         75166
# country                      74745
# reserved_room_type           75166
# assigned_room_type           75166
# customer_type                75166
# reservation_status           75166
# reservation_status_date      75166
# total_kids                   75166
# has_kids                     75166
# dtype: int64
